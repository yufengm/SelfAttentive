# %% [markdown]
# # Performance Comparison

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt


print 'Performance with basic LSTM Model'
image = mpimg.imread( 'Results/noise & no stem/BasicLSTM.png' )

plt.axis('off')
plt.imshow( image )
plt.show()

print 'Performance with Self-Attentive Model'
image = mpimg.imread( 'Results/noise & no stem/AttentionResults.png' )
plt.axis('off')
plt.imshow( image )
plt.show()

print 'Performance with Self-Attentive Model - Noise Removed & Stemmed'
image = mpimg.imread( 'Results/no noise & stem 500/AttentionResults-500.png' )
plt.axis('off')
plt.imshow( image )
plt.show()
# Out:
# Performance with basic LSTM Model
# Performance with Self-Attentive Model
# Performance with Self-Attentive Model - Noise Removed & Stemmed

# %% [markdown]
# # Loading Attention Weights

# %%
import torch

cuda = True
path = 'data/'
test_batch_size = 32

# Load Attention weights
Weights = torch.load( 'Results/no noise & stem 500/attention_weights.pt' )

# %% [markdown]
# # Review Loading and Tokenization

# %%
import csv
from nltk.tokenize import word_tokenize

ReviewsAndTokens = []
count = 0
# Test dataset
with open( path + 'test.csv', 'r' ) as f:
    Reader = csv.reader( f, delimiter=',', quoting=csv.QUOTE_MINIMAL )
    for i, record in enumerate( Reader ):
        content = record[ 0 ]
        tokens = content.decode('utf-8').split()
        
        temp = [ content, tokens, record[1] ]
        ReviewsAndTokens.append( temp )
        count += 1
    
nbatch = count // test_batch_size
batchifiable = nbatch * test_batch_size

batchedReviewsAndTokens = ReviewsAndTokens[ :batchifiable ]

# %%
reviewAndweights = []
for i in range( 0, batchifiable - 1, test_batch_size ):

    for j in range( test_batch_size ):
        record = batchedReviewsAndTokens[ i+j ]
        record.extend( [ i, j ] )
        reviewAndweights.append( record )

# %% [markdown]
# # Attention Visualization on Reviews

# %%
def Highlight( string ):
    return "\x1b[31m" + string + "\x1b[0m"

reviewNum = 20
start = 2400
end = start + reviewNum
words2show = 5

for reviewID in range( start , end ):
    sample_review = batchedReviewsAndTokens[ reviewID ][ 0 ]
    sample_tokens = batchedReviewsAndTokens[ reviewID ][ 1 ]
    helpful = batchedReviewsAndTokens[ reviewID ][ 2 ]
    weights = Weights[ batchedReviewsAndTokens[ reviewID ][3] ][ 0 ][ batchedReviewsAndTokens[ reviewID ][ 4 ] ].data
    
    # print weights

    vector = weights.sum( 0 )
    vector = vector / vector.sum( 1 )[ 0,0 ]
    att, ids_to_show =  vector.sort( 1, descending=True )

    ids_to_show = ids_to_show.squeeze( 0 ).tolist()[:words2show]

    print 'Sample Review:'

    sent = ''
    for idx in range( len( sample_tokens ) ):
        if idx in ids_to_show:
            sent += ' ' + Highlight( sample_tokens[ idx ] )
        else:
            sent += ' ' + sample_tokens[ idx ]
    print sent
    
    print ''
    print 'Helpful?'
    print helpful
    print ''
        
    print '--' * 59
# Out:
# 1.00000e-02 *
#  2.9110  2.6591  2.5222  ...   2.6045  2.7159  2.6670
#  2.8238  2.7034  2.9204  ...   2.8850  3.2329  3.0066
#  2.4397  2.2837  2.4049  ...   2.7426  2.4930  2.4987
#           ...             ⋱             ...
#  2.7938  2.6180  2.7357  ...   2.6430  2.5396  2.5874
#  2.4690  2.8087  2.7440  ...   2.8696  2.7271  2.6102
#  2.8588  2.8504  2.6499  ...   2.8915  2.8598  2.6856
# [torch.cuda.FloatTensor of size 30x36 (GPU 0)]
#
# Sample Review:
#  i stay in the hotel for a work event and enjoy it . spacious room , balcony , comfortable and quiet . close to attraction and nice spot to walk . clean and well appoint .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.1082  2.7854  2.8332  ...   2.9559  2.9055  2.7471
#  2.6808  2.8137  2.8157  ...   2.9376  2.9014  2.7341
#  2.7425  2.6977  2.8735  ...   2.9731  2.8901  2.7286
#           ...             ⋱             ...
#  2.9366  2.7442  2.6518  ...   2.6077  2.7272  2.6893
#  2.5318  2.5924  2.7733  ...   2.7003  3.1378  2.9019
#  2.9356  3.0444  2.6535  ...   2.8507  2.6340  2.6861
# [torch.cuda.FloatTensor of size 30x36 (GPU 0)]
#
# Sample Review:
#  i be desi . dont expect much . big negative , ac keep turn on n off . huge annoyance . if u r light sleeper like me u wont be sleep much i guereentee .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.7516  2.8468  2.6398  ...   2.8387  2.7791  3.1114
#  2.5799  2.7275  3.1144  ...   2.7475  2.8990  2.8819
#  2.8381  2.6990  2.9147  ...   2.8397  2.6048  2.7393
#           ...             ⋱             ...
#  2.9777  2.9486  2.7859  ...   2.7670  2.5555  2.8129
#  2.9069  2.7173  2.6131  ...   2.7966  2.8191  2.9936
#  2.7968  2.7797  2.5759  ...   2.7723  2.6674  2.7262
# [torch.cuda.FloatTensor of size 30x36 (GPU 0)]
#
# Sample Review:
#  well at $ 600 a night it better be good ! and it wasn ' t too shabby ! not worth it all the time ! much fancier place to stay with more personal service !
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.9972  3.0226  3.2395  ...   2.6162  2.6431  2.8702
#  2.7132  2.5134  2.6537  ...   3.2354  3.0681  2.9614
#  2.9923  3.2618  2.7364  ...   2.3794  2.4347  2.5048
#           ...             ⋱             ...
#  3.0551  3.1182  3.0744  ...   2.3376  2.4628  2.5663
#  2.6973  2.8794  2.6477  ...   2.6642  2.9059  3.0802
#  2.8179  2.7318  2.7242  ...   2.6802  2.7224  2.5807
# [torch.cuda.FloatTensor of size 30x36 (GPU 0)]
#
# Sample Review:
#  really enjoy my stay . room be clean , spacious and quiet . from front desk to housekeep everyone be very helpful and accommodate . would definitely stay here again and will recommend to others !
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.8527  2.8243  2.6912  ...   2.8500  2.8418  3.0208
#  2.4193  2.5152  2.7670  ...   2.6974  2.9227  2.9935
#  2.5546  2.7917  2.8842  ...   2.7919  2.7443  2.8246
#           ...             ⋱             ...
#  2.9629  2.9478  2.8442  ...   2.6477  2.6448  2.8130
#  2.9334  2.8918  2.9413  ...   2.8363  2.8052  3.0704
#  2.8263  2.8788  2.6199  ...   2.9811  2.8724  2.6912
# [torch.cuda.FloatTensor of size 30x36 (GPU 0)]
#
# Sample Review:
#  stay here for a week with my wife and two kid . the room be okay but the people and service be exceptional ! ! i would recommend this hotel and would stay here again !
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.8456  2.7652  2.7876  ...   3.1368  2.8926  2.9873
#  2.6083  2.8182  3.0479  ...   2.8108  3.0952  3.1541
#  2.7956  3.1113  3.0104  ...   2.7578  2.7544  2.7580
#           ...             ⋱             ...
#  3.0202  2.8541  3.0389  ...   2.9608  2.7481  2.6848
#  2.6023  2.7386  2.6986  ...   2.7016  2.8928  3.2026
#  3.1696  3.0477  2.6511  ...   2.8304  2.9995  2.7595
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  be there a negative star ? ! ? the staff here be horrible and dismissive ! ( other than miguel ) . what a pathetic place of business . book at your own risk !
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.7470  3.2099  3.0580  ...   3.4905  3.4547  3.4774
#  2.6299  2.5654  2.7260  ...   2.3870  2.5278  2.7938
#  4.1549  3.7227  3.1764  ...   3.0422  3.2380  2.9980
#           ...             ⋱             ...
#  3.3802  3.5114  3.4665  ...   3.2698  3.1696  2.9711
#  3.4470  3.0443  2.9330  ...   3.1725  2.9867  3.1982
#  2.7604  2.9449  2.6689  ...   2.5943  2.7580  2.7542
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  nice quiet building , friendly staff . only complaint would be have to take the bus everywhere , but we didnt wait more then 10 minute for one . love the pirate theme room !
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.8816  2.8856  2.5627  ...   2.9129  2.7806  2.7666
#  2.8724  3.0476  2.9980  ...   3.0277  3.1062  2.9929
#  2.7988  2.8295  2.6710  ...   2.6459  2.9158  2.9228
#           ...             ⋱             ...
#  2.9243  2.8254  2.5383  ...   2.6637  2.6698  2.7229
#  2.6002  2.7324  2.6597  ...   2.6619  2.7257  2.7466
#  2.9414  2.6638  2.7820  ...   2.7887  2.9363  2.7794
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  they steal several item from my room , small room , bad breakfast , egg everyday and cold waffle . the staff be not friendly and didn ' t care to help at all .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.2140  3.1851  2.7312  ...   3.0094  3.2277  2.8145
#  2.8498  2.7463  3.0276  ...   2.8242  2.9867  2.9040
#  2.5520  2.8850  2.7024  ...   2.9010  3.8256  3.0490
#           ...             ⋱             ...
#  3.3062  3.1715  2.7404  ...   3.0665  2.8499  2.7380
#  3.0400  3.3301  2.8845  ...   2.6161  2.9793  2.9098
#  3.0555  3.0228  3.0015  ...   3.1962  2.8097  2.7412
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  terrible place to stay for a business traveler . if on vacation , you ' ll like the location but get exactly what you pay for . the hilton across the street be nicer .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.2061  3.5974  2.8911  ...   2.5838  2.4688  2.5744
#  2.6087  2.7029  2.6285  ...   3.2201  3.0540  3.0343
#  3.3926  4.0517  3.0922  ...   2.8882  2.3904  2.6576
#           ...             ⋱             ...
#  3.2645  3.2940  3.1629  ...   2.5248  2.5267  2.6295
#  3.0289  3.2067  2.9396  ...   2.5891  2.4662  2.5941
#  3.2751  2.9742  3.0500  ...   2.8954  2.7081  2.7615
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  very nice and room be very comfortable . however the main shower head wasn ' t working and have to use the 2ndary shower head , which kind of sucked but i get by .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.2282  3.5354  3.1896  ...   2.8655  3.0315  2.9691
#  2.5711  2.5624  2.7266  ...   2.5789  2.6532  2.8470
#  2.6164  2.9939  2.9059  ...   3.3329  3.2892  3.0706
#           ...             ⋱             ...
#  3.1234  3.3912  3.1287  ...   2.7928  2.9719  2.7918
#  2.5846  3.0004  2.6666  ...   3.2279  2.9329  2.7779
#  2.7461  2.9509  3.2739  ...   3.3555  2.8628  2.8173
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  this place be very dirty , customer service be a joke and definitely not a 3 star hotel . stay away from it and pay 20 more buck for a decent , safe room .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.2287  2.9718  2.8441  ...   3.0218  2.9258  2.8415
#  2.5613  2.5235  2.8551  ...   3.4012  3.3062  3.0371
#  3.2641  3.4044  3.1720  ...   3.1450  2.6652  2.6603
#           ...             ⋱             ...
#  2.8645  3.0771  2.9089  ...   3.1381  2.9331  2.7888
#  3.1740  2.8837  2.8118  ...   3.2812  3.0839  2.9555
#  2.4463  2.4273  2.6921  ...   2.9890  2.6517  2.6089
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  favorite pool ever . the room be clean and look like it have be remodel recently . my only complaint would have to be that the lobby be over perfumed cause a mild headache .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.0660  2.6066  2.7859  ...   3.0030  3.1036  2.8185
#  2.8623  2.7071  2.7762  ...   3.0249  3.3383  2.9383
#  2.7970  2.6638  2.5797  ...   2.7114  3.0204  2.8695
#           ...             ⋱             ...
#  3.5735  3.0961  3.0274  ...   2.7648  2.8058  2.8221
#  3.5124  3.3831  3.1767  ...   2.6501  2.9360  2.9722
#  2.4570  2.6831  2.9138  ...   3.0915  3.0105  2.7288
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  dirty , loud and old . cheap , but not worth it . you ' d need to be really desperate . seem to be go downhill , because it use to be ok .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.0906  3.1635  3.5211  ...   3.1675  3.3987  3.1623
#  2.9131  2.8748  3.1552  ...   2.7889  3.0164  2.8314
#  2.6484  2.9944  3.1746  ...   2.9353  3.4233  3.0570
#           ...             ⋱             ...
#  3.0084  3.2245  3.2282  ...   2.9097  2.9716  3.0423
#  2.5699  2.6015  2.8089  ...   2.6786  2.8844  2.8275
#  2.7523  3.0532  3.0252  ...   2.7232  2.5597  2.7346
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  customer care awful rude upper staff . remotes don ' t work no maid , service for a week , shower no power . never stay , there again . vacation village at parkway .
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.7975  2.9194  2.7053  ...   2.8016  2.8256  2.8291
#  2.6688  2.8066  2.8375  ...   2.8827  3.2220  2.9849
#  2.5478  2.7860  2.9022  ...   3.0420  2.8685  2.6709
#           ...             ⋱             ...
#  2.9236  2.8663  2.7563  ...   3.1351  2.7328  2.8726
#  2.3498  2.4704  2.7391  ...   3.0403  2.9145  2.7340
#  3.3626  3.3184  3.1369  ...   2.6839  2.5321  2.6747
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  if you want a quiet night on your business trip this be the place to be . plus , complimentary full hot breakfast and fast easy access to the research park via science drive .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.8387  2.9444  3.2799  ...   2.8839  3.2812  3.2493
#  2.7486  2.9677  3.0307  ...   3.0794  3.1610  2.8672
#  2.7904  2.6347  2.7924  ...   2.7323  2.9204  3.1388
#           ...             ⋱             ...
#  2.7129  3.0710  3.4261  ...   2.9122  3.3186  3.1376
#  2.6945  2.8652  2.8216  ...   2.9011  2.8871  3.2317
#  2.7121  2.5453  2.7974  ...   2.5606  2.7436  2.6416
# [torch.cuda.FloatTensor of size 30x35 (GPU 0)]
#
# Sample Review:
#  it the happiest place on earth ! or in reality it can be the most stressful place long line very crowd place veeeery hoooot ! but if you can stand that it the happiest place
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.2105  3.1501  3.3921  ...   2.8674  3.3942  3.3960
#  2.5909  2.7158  3.0016  ...   3.1602  3.2202  2.9907
#  2.6259  2.6393  2.6850  ...   3.6580  3.1553  2.9832
#           ...             ⋱             ...
#  3.2209  3.1526  3.1394  ...   2.6083  2.9114  3.0102
#  2.6791  2.7426  2.8408  ...   2.8601  3.2438  3.3968
#  2.6749  2.9999  2.7648  ...   2.6497  2.5243  2.6424
# [torch.cuda.FloatTensor of size 30x34 (GPU 0)]
#
# Sample Review:
#  this be my 5th year stay here and it be awesome . they handle all of our need and take care of any issue that we may have . thanks so much floridays !
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.0808  3.1464  2.9252  ...   2.8444  2.8078  2.8526
#  2.8316  2.7962  2.9080  ...   3.1319  2.8041  2.9646
#  2.8666  2.4982  2.7488  ...   2.7648  2.8644  2.9520
#           ...             ⋱             ...
#  2.9474  3.2708  3.0894  ...   2.7899  2.7768  2.8324
#  2.8840  3.6526  3.3026  ...   3.0105  3.0390  2.7930
#  3.1064  2.7104  2.6797  ...   2.7742  2.9338  2.9647
# [torch.cuda.FloatTensor of size 30x34 (GPU 0)]
#
# Sample Review:
#  it ' s a basic motel . bed r comfortable . enough room to stay . don ' t expect a 5 star with the cheap price . not bad for the night .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  2.8936  2.9043  3.1287  ...   3.1793  3.1054  2.9940
#  2.7511  2.9598  3.0190  ...   2.8937  2.8905  2.8856
#  2.9274  3.0399  2.8193  ...   2.6973  2.6993  2.7265
#           ...             ⋱             ...
#  3.0726  2.9134  3.0150  ...   2.9058  2.9191  2.9474
#  2.6486  2.7507  2.7613  ...   3.1484  3.1658  3.2068
#  3.1360  2.9954  3.0631  ...   3.0051  2.8820  2.7236
# [torch.cuda.FloatTensor of size 30x34 (GPU 0)]
#
# Sample Review:
#  they lose my car ! ! ! ! i ' ve be wait for over 1hr and valet still can ' t find it . . . unbelievable ! ! ! ! ! !
#
# Helpful?
# 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
# 1.00000e-02 *
#  3.1032  3.1375  3.1732  ...   2.9699  2.8777  2.9094
#  2.8322  2.9400  3.1450  ...   3.1397  2.9998  3.0071
#  2.6463  2.3878  2.6044  ...   3.0038  2.9093  2.9451
#           ...             ⋱             ...
#  2.9007  3.0608  3.0220  ...   3.0081  2.8962  2.8468
#  2.8349  3.5547  3.1819  ...   3.0089  3.0118  2.9582
#  3.3236  2.6627  2.5979  ...   2.8337  3.0264  2.8745
# [torch.cuda.FloatTensor of size 30x34 (GPU 0)]
#
# Sample Review:
#  we ' ve stay here about a dozen time . they be the best . room be always specular , front desk professional - lot of activity . truly a place of rest .
#
# Helpful?
# 1
#
# ----------------------------------------------------------------------------------------------------------------------
